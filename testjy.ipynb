# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# $s^2= {\d + f /sdf$}\CDOT{\sdf+5}

# %%
x = np.linspace(0,20,100)
plt.plot(x, np.sin(x))
plt.show()

# %%
msg = "Test"
print(msg)
# Out:
# Test
